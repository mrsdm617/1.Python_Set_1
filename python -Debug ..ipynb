# %% [markdown]
# #1.Find the error in the following Python code:
#
#  for i in range(5)
#     print(i)
#  # Colon is missed

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #2.What will be the output of this code?
#
# a = 10
# b = "5"
# print(a + b)
# # b is not an integer

# %%
a = 10
b = "5"
print(a +int(b))
# Out:
# 15

# %% [markdown]
# #3.What is the issue in this Python snippet?
#
#  def add_numbers(a, b)
#     return a + b
# # colon is missed in def

# %%
def add_numbers(a, b):
    return a + b

# %%
add_numbers(7,4)
# Out:
# 11

# %% [markdown]
# #4.Identify the bug in the following Python code:
#
#  numbers = [1, 2, 3, 4]
# print(numbers[4])
# # IndexError - only 4 elements are found, in question it seeks fifth element

# %%
numbers = [1, 2, 3, 4]
print(numbers[0])
# Out:
# 1

# %% [markdown]
# #5.Find the error in the following Python code:
# print "Hello, World!"
# # parentheses is missed

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# #6.Find the error in the following Python code:
# x = 5 / 0
# # ZeroDivisionError: division by zero

# %% [markdown]
# #7.Find the error in the following Python code:name = "Alice"
# age = 25
# print("Name: " + name + ", Age: " + age)
# # TypeError: can only concatenate str (not "int") to str

# %%
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %% [markdown]
# #8.Find the error
# for i in range(1, 10, -1):
#     print(i)
# # negative step means counting down, the start value must be greater than the stop value, otherwise the range is empty

# %%
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %% [markdown]
# #9. Find the error in the following Python code:
# x = 10
# if x = 5:
#     print("x is 5")
# # := is the walrus operator, to assign the value 5 to x

# %%
x = 10
if x := 5:
    print("x is 5")
# Out:
# x is 5

# %% [markdown]
# #10. Identify the error in the following function definition:
#
# def greet(name)
#     print("Hello, " + name)
#
# # SyntaxError : is missed

# %%
def greet(name):
    print("Hello, " + name)

# %%
greet("Vije")
# Out:
# Hello, Vije
